# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# Import the time module.
import time

# Import the API key.
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
 # Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city and ensure imperial data is requested
    city_url = url + "&q=" + city + '&units=imperial'

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
               
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | leningradskiy
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | cidreira
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | maniitsoq
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | moreira sales
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | whitehorse
# Processing Record 13 of Set 1 | saskylakh
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | buraydah
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 18 of Set 1 | bambous virieux
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | upernavik
# Processing Record 21 of Set 1 | sur
# Processing Record 22 of Set 1 | rawson
# Processing Record 23 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 1 | moussoro
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | pau dos ferros
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | constitucion
# Processing Record 30 of Set 1 | lovozero
# Processing Record 31 of Set 1 | codrington
# Processing Record 32 of Set 1 | umea
# Processing Record 33 of Set 1 | sao mateus
# Processing Record 34 of Set 1 | trairi
# Processing Record 35 of Set 1 | tura
# Processing Record 36 of Set 1 | tukrah
# Processing Record 37 of Set 1 | mola di bari
# Processing Record 38 of Set 1 | san alberto
# Processing Record 39 of Set 1 | chokurdakh
# Processing Record 40 of Set 1 | talnakh
# Processing Record 41 of Set 1 | saint george
# Processing Record 42 of Set 1 | nanortalik
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | fort nelson
# Processing Record 45 of Set 1 | ucluelet
# Processing Record 46 of Set 1 | luderitz
# Processing Record 47 of Set 1 | rio grande
# Processing Record 48 of Set 1 | laukaa
# Processing Record 49 of Set 1 | antofagasta
# Processing Record 50 of Set 1 | cullman
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | hervey bay
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | saint-paul
# Processing Record 9 of Set 2 | touros
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | thunder bay
# Processing Record 12 of Set 2 | tianpeng
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | lebedinyy
# Processing Record 15 of Set 2 | concordia
# Processing Record 16 of Set 2 | yulara
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | dikson
# Processing Record 20 of Set 2 | sitka
# Processing Record 21 of Set 2 | senj
# Processing Record 22 of Set 2 | comodoro rivadavia
# Processing Record 23 of Set 2 | fayaoue
# Processing Record 24 of Set 2 | olafsvik
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | severo-kurilsk
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | marsh harbour
# Processing Record 30 of Set 2 | necocli
# Processing Record 31 of Set 2 | manta
# Processing Record 32 of Set 2 | urumqi
# Processing Record 33 of Set 2 | kuliyapitiya
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | huarmey
# Processing Record 36 of Set 2 | hunchun
# Processing Record 37 of Set 2 | karratha
# Processing Record 38 of Set 2 | santa marta
# Processing Record 39 of Set 2 | pisco
# Processing Record 40 of Set 2 | hilo
# Processing Record 41 of Set 2 | hasaki
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | butaritari
# Processing Record 44 of Set 2 | asosa
# Processing Record 45 of Set 2 | kandrian
# Processing Record 46 of Set 2 | jieshi
# Processing Record 47 of Set 2 | avarua
# Processing Record 48 of Set 2 | xingyi
# Processing Record 49 of Set 2 | myaundzha
# Processing Record 50 of Set 2 | pangnirtung
# Processing Record 1 of Set 3 | mayya
# Processing Record 2 of Set 3 | provideniya
# Processing Record 3 of Set 3 | charters towers
# Processing Record 4 of Set 3 | neryungri
# Processing Record 5 of Set 3 | bluff
# Processing Record 6 of Set 3 | saint-augustin
# Processing Record 7 of Set 3 | tilichiki
# Processing Record 8 of Set 3 | kudahuvadhoo
# Processing Record 9 of Set 3 | longyearbyen
# Processing Record 10 of Set 3 | ho chi minh city
# Processing Record 11 of Set 3 | okhotsk
# Processing Record 12 of Set 3 | mananjary
# Processing Record 13 of Set 3 | kirakira
# Processing Record 14 of Set 3 | klaksvik
# Processing Record 15 of Set 3 | kodiak
# Processing Record 16 of Set 3 | tevaitoa
# Processing Record 17 of Set 3 | northam
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | faanui
# Processing Record 20 of Set 3 | san borja
# Processing Record 21 of Set 3 | kirkwall
# Processing Record 22 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 3 | zabid
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 3 | narimanov
# Processing Record 27 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 3 | malya
# Processing Record 29 of Set 3 | ulaangom
# Processing Record 30 of Set 3 | druzhba
# Processing Record 31 of Set 3 | fortuna
# Processing Record 32 of Set 3 | bredasdorp
# Processing Record 33 of Set 3 | mahebourg
# Processing Record 34 of Set 3 | lorengau
# Processing Record 35 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 3 | hudson bay
# Processing Record 37 of Set 3 | forbes
# Processing Record 38 of Set 3 | yellowknife
# Processing Record 39 of Set 3 | rocha
# Processing Record 40 of Set 3 | mataura
# Processing Record 41 of Set 3 | warri
# Processing Record 42 of Set 3 | boston
# Processing Record 43 of Set 3 | saiha
# Processing Record 44 of Set 3 | wentzville
# Processing Record 45 of Set 3 | praia
# Processing Record 46 of Set 3 | saint-joseph
# Processing Record 47 of Set 3 | georgetown
# Processing Record 48 of Set 3 | makakilo city
# Processing Record 49 of Set 3 | richards bay
# Processing Record 50 of Set 3 | onega
# Processing Record 1 of Set 4 | husavik
# Processing Record 2 of Set 4 | castanos
# Processing Record 3 of Set 4 | cayenne
# Processing Record 4 of Set 4 | muros
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | odweyne
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | ponta do sol
# Processing Record 9 of Set 4 | aksarka
# Processing Record 10 of Set 4 | trat
# Processing Record 11 of Set 4 | palmas
# Processing Record 12 of Set 4 | kasongo-lunda
# Processing Record 13 of Set 4 | troitsko-pechorsk
# Processing Record 14 of Set 4 | sudbury
# Processing Record 15 of Set 4 | beringovskiy
# Processing Record 16 of Set 4 | khatanga
# Processing Record 17 of Set 4 | himatnagar
# Processing Record 18 of Set 4 | tessalit
# Processing Record 19 of Set 4 | yumen
# Processing Record 20 of Set 4 | phuket
# Processing Record 21 of Set 4 | vigrestad
# Processing Record 22 of Set 4 | deputatskiy
# Processing Record 23 of Set 4 | dosso
# Processing Record 24 of Set 4 | guerrero negro
# Processing Record 25 of Set 4 | pacific grove
# Processing Record 26 of Set 4 | esperance
# Processing Record 27 of Set 4 | nome
# Processing Record 28 of Set 4 | jiexiu
# Processing Record 29 of Set 4 | madaoua
# Processing Record 30 of Set 4 | santa rosa
# Processing Record 31 of Set 4 | muravlenko
# Processing Record 32 of Set 4 | puerto madryn
# Processing Record 33 of Set 4 | asyut
# Processing Record 34 of Set 4 | yabrud
# Processing Record 35 of Set 4 | beira
# Processing Record 36 of Set 4 | puertollano
# Processing Record 37 of Set 4 | ancud
# Processing Record 38 of Set 4 | havre-saint-pierre
# Processing Record 39 of Set 4 | rovaniemi
# Processing Record 40 of Set 4 | vanimo
# Processing Record 41 of Set 4 | walvis bay
# Processing Record 42 of Set 4 | broome
# Processing Record 43 of Set 4 | hermosillo
# Processing Record 44 of Set 4 | nizhneshilovka
# City not found. Skipping...
# Processing Record 45 of Set 4 | falmouth
# Processing Record 46 of Set 4 | makokou
# Processing Record 47 of Set 4 | coihaique
# Processing Record 48 of Set 4 | soure
# Processing Record 49 of Set 4 | chippewa falls
# Processing Record 50 of Set 4 | kalisz
# Processing Record 1 of Set 5 | chuy
# Processing Record 2 of Set 5 | port moresby
# Processing Record 3 of Set 5 | aksha
# Processing Record 4 of Set 5 | hamilton
# Processing Record 5 of Set 5 | rincon
# Processing Record 6 of Set 5 | adrar
# Processing Record 7 of Set 5 | faya
# Processing Record 8 of Set 5 | new norfolk
# Processing Record 9 of Set 5 | waipawa
# Processing Record 10 of Set 5 | malakal
# Processing Record 11 of Set 5 | talkha
# Processing Record 12 of Set 5 | kochubey
# Processing Record 13 of Set 5 | krechevitsy
# Processing Record 14 of Set 5 | flinders
# Processing Record 15 of Set 5 | thompson
# Processing Record 16 of Set 5 | beloha
# Processing Record 17 of Set 5 | shimanovsk
# Processing Record 18 of Set 5 | manjeshwar
# Processing Record 19 of Set 5 | veselynove
# Processing Record 20 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 5 | coracao de jesus
# Processing Record 22 of Set 5 | tahta
# Processing Record 23 of Set 5 | mar del plata
# Processing Record 24 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 5 | loknya
# Processing Record 26 of Set 5 | deer lake
# Processing Record 27 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 5 | pereira barreto
# Processing Record 31 of Set 5 | clyde river
# Processing Record 32 of Set 5 | labuhan
# Processing Record 33 of Set 5 | tabuk
# Processing Record 34 of Set 5 | port hedland
# Processing Record 35 of Set 5 | kavieng
# Processing Record 36 of Set 5 | barroualie
# City not found. Skipping...
# Processing Record 37 of Set 5 | alberdi
# Processing Record 38 of Set 5 | half moon bay
# Processing Record 39 of Set 5 | jalu
# Processing Record 40 of Set 5 | hambantota
# Processing Record 41 of Set 5 | kopyevo
# City not found. Skipping...
# Processing Record 42 of Set 5 | praya
# Processing Record 43 of Set 5 | padang
# Processing Record 44 of Set 5 | piranhas
# Processing Record 45 of Set 5 | hofn
# Processing Record 46 of Set 5 | pafos
# Processing Record 47 of Set 5 | alta floresta
# Processing Record 48 of Set 5 | saint-philippe
# Processing Record 49 of Set 5 | port macquarie
# Processing Record 50 of Set 5 | esso
# Processing Record 1 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 6 | east london
# Processing Record 3 of Set 6 | farah
# Processing Record 4 of Set 6 | zavetnoye
# Processing Record 5 of Set 6 | clermont
# Processing Record 6 of Set 6 | airai
# Processing Record 7 of Set 6 | mount isa
# Processing Record 8 of Set 6 | kouango
# Processing Record 9 of Set 6 | havoysund
# Processing Record 10 of Set 6 | nuuk
# Processing Record 11 of Set 6 | prince rupert
# Processing Record 12 of Set 6 | kupang
# Processing Record 13 of Set 6 | krasnyy chikoy
# Processing Record 14 of Set 6 | mapiripan
# Processing Record 15 of Set 6 | impfondo
# Processing Record 16 of Set 6 | vardo
# Processing Record 17 of Set 6 | lata
# Processing Record 18 of Set 6 | kaitangata
# Processing Record 19 of Set 6 | davila
# Processing Record 20 of Set 6 | kangaatsiaq
# Processing Record 21 of Set 6 | nedjo
# Processing Record 22 of Set 6 | maketu
# Processing Record 23 of Set 6 | pochutla
# Processing Record 24 of Set 6 | matara
# Processing Record 25 of Set 6 | boromo
# Processing Record 26 of Set 6 | kashi
# Processing Record 27 of Set 6 | saldanha
# Processing Record 28 of Set 6 | bathsheba
# Processing Record 29 of Set 6 | candido mendes
# Processing Record 30 of Set 6 | cherskiy
# Processing Record 31 of Set 6 | gat
# Processing Record 32 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | darnah
# Processing Record 34 of Set 6 | eydhafushi
# Processing Record 35 of Set 6 | isetskoye
# Processing Record 36 of Set 6 | lebu
# Processing Record 37 of Set 6 | gorzow wielkopolski
# Processing Record 38 of Set 6 | torbay
# Processing Record 39 of Set 6 | mersing
# Processing Record 40 of Set 6 | svetlyy
# Processing Record 41 of Set 6 | garut
# Processing Record 42 of Set 6 | suntar
# Processing Record 43 of Set 6 | santa isabel do rio negro
# Processing Record 44 of Set 6 | la ronge
# Processing Record 45 of Set 6 | yako
# Processing Record 46 of Set 6 | gayny
# Processing Record 47 of Set 6 | martapura
# Processing Record 48 of Set 6 | coulihaut
# City not found. Skipping...
# Processing Record 49 of Set 6 | balkhash
# Processing Record 50 of Set 6 | tezu
# Processing Record 1 of Set 7 | qabis
# City not found. Skipping...
# Processing Record 2 of Set 7 | sokoni
# Processing Record 3 of Set 7 | rosarito
# Processing Record 4 of Set 7 | sao filipe
# Processing Record 5 of Set 7 | lasa
# Processing Record 6 of Set 7 | komsomolskiy
# Processing Record 7 of Set 7 | prado
# Processing Record 8 of Set 7 | hobyo
# Processing Record 9 of Set 7 | oistins
# Processing Record 10 of Set 7 | caravelas
# Processing Record 11 of Set 7 | meinung
# City not found. Skipping...
# Processing Record 12 of Set 7 | ukiah
# Processing Record 13 of Set 7 | talas
# Processing Record 14 of Set 7 | alofi
# Processing Record 15 of Set 7 | dahanu
# Processing Record 16 of Set 7 | san joaquin
# Processing Record 17 of Set 7 | sao joao da barra
# Processing Record 18 of Set 7 | uaua
# Processing Record 19 of Set 7 | dobryanka
# Processing Record 20 of Set 7 | lavrentiya
# Processing Record 21 of Set 7 | arman
# Processing Record 22 of Set 7 | namatanai
# Processing Record 23 of Set 7 | khash
# Processing Record 24 of Set 7 | ekhabi
# Processing Record 25 of Set 7 | neiafu
# Processing Record 26 of Set 7 | nhulunbuy
# Processing Record 27 of Set 7 | liverpool
# Processing Record 28 of Set 7 | ilesha
# Processing Record 29 of Set 7 | nantucket
# Processing Record 30 of Set 7 | sirari
# Processing Record 31 of Set 7 | bosaso
# Processing Record 32 of Set 7 | victoria
# Processing Record 33 of Set 7 | kitob
# Processing Record 34 of Set 7 | kidal
# Processing Record 35 of Set 7 | gigmoto
# Processing Record 36 of Set 7 | byron bay
# Processing Record 37 of Set 7 | sooke
# Processing Record 38 of Set 7 | arraial do cabo
# Processing Record 39 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 7 | iquitos
# Processing Record 41 of Set 7 | nyurba
# Processing Record 42 of Set 7 | vestmanna
# Processing Record 43 of Set 7 | wawa
# Processing Record 44 of Set 7 | acajutla
# Processing Record 45 of Set 7 | loa janan
# Processing Record 46 of Set 7 | songjianghe
# Processing Record 47 of Set 7 | benghazi
# Processing Record 48 of Set 7 | tasiilaq
# Processing Record 49 of Set 7 | ahipara
# Processing Record 50 of Set 7 | pandan
# Processing Record 1 of Set 8 | ostrovnoy
# Processing Record 2 of Set 8 | ikongo
# Processing Record 3 of Set 8 | namtsy
# Processing Record 4 of Set 8 | formosa do rio preto
# Processing Record 5 of Set 8 | manaia
# Processing Record 6 of Set 8 | puerto plata
# Processing Record 7 of Set 8 | necochea
# Processing Record 8 of Set 8 | mayo
# Processing Record 9 of Set 8 | chake chake
# Processing Record 10 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 8 | pankrushikha
# Processing Record 12 of Set 8 | warrington
# Processing Record 13 of Set 8 | zhanakorgan
# Processing Record 14 of Set 8 | harlingen
# Processing Record 15 of Set 8 | brownwood
# Processing Record 16 of Set 8 | ballina
# Processing Record 17 of Set 8 | meulaboh
# Processing Record 18 of Set 8 | biak
# Processing Record 19 of Set 8 | souillac
# Processing Record 20 of Set 8 | rio tercero
# Processing Record 21 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 22 of Set 8 | jacmel
# Processing Record 23 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 24 of Set 8 | salalah
# Processing Record 25 of Set 8 | miyako
# Processing Record 26 of Set 8 | muskogee
# Processing Record 27 of Set 8 | palmer
# Processing Record 28 of Set 8 | boa vista
# Processing Record 29 of Set 8 | abu samrah
# Processing Record 30 of Set 8 | gopalur
# Processing Record 31 of Set 8 | naze
# Processing Record 32 of Set 8 | dzaoudzi
# Processing Record 33 of Set 8 | hovd
# Processing Record 34 of Set 8 | tynda
# Processing Record 35 of Set 8 | gushi
# Processing Record 36 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 8 | najran
# Processing Record 38 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 8 | fomboni
# Processing Record 40 of Set 8 | tautira
# Processing Record 41 of Set 8 | vanavara
# Processing Record 42 of Set 8 | kokoda
# Processing Record 43 of Set 8 | milkovo
# Processing Record 44 of Set 8 | iberia
# Processing Record 45 of Set 8 | los llanos de aridane
# Processing Record 46 of Set 8 | camacha
# Processing Record 47 of Set 8 | ardmore
# Processing Record 48 of Set 8 | bibbiena
# Processing Record 49 of Set 8 | san patricio
# Processing Record 50 of Set 8 | tuatapere
# Processing Record 1 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 9 | norman wells
# Processing Record 3 of Set 9 | ambon
# Processing Record 4 of Set 9 | marawi
# Processing Record 5 of Set 9 | vidim
# Processing Record 6 of Set 9 | coquimbo
# Processing Record 7 of Set 9 | itanagar
# Processing Record 8 of Set 9 | ciudad bolivar
# Processing Record 9 of Set 9 | tornio
# Processing Record 10 of Set 9 | nouna
# Processing Record 11 of Set 9 | manaure
# Processing Record 12 of Set 9 | moyale
# Processing Record 13 of Set 9 | ilulissat
# Processing Record 14 of Set 9 | kimbe
# Processing Record 15 of Set 9 | sakakah
# Processing Record 16 of Set 9 | selkirk
# Processing Record 17 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 9 | nampula
# Processing Record 19 of Set 9 | opuwo
# Processing Record 20 of Set 9 | san jose
# Processing Record 21 of Set 9 | houma
# Processing Record 22 of Set 9 | kaura namoda
# Processing Record 23 of Set 9 | sinegorye
# Processing Record 24 of Set 9 | pondicherry
# Processing Record 25 of Set 9 | saint-georges
# Processing Record 26 of Set 9 | sibolga
# Processing Record 27 of Set 9 | porto santo
# Processing Record 28 of Set 9 | lhokseumawe
# Processing Record 29 of Set 9 | dubbo
# Processing Record 30 of Set 9 | dingle
# Processing Record 31 of Set 9 | vila franca do campo
# Processing Record 32 of Set 9 | porto novo
# Processing Record 33 of Set 9 | aksu
# Processing Record 34 of Set 9 | cooma
# Processing Record 35 of Set 9 | shahjahanpur
# Processing Record 36 of Set 9 | itarema
# Processing Record 37 of Set 9 | kaspiysk
# Processing Record 38 of Set 9 | la asuncion
# Processing Record 39 of Set 9 | vicente guerrero
# Processing Record 40 of Set 9 | sibu
# Processing Record 41 of Set 9 | isla vista
# Processing Record 42 of Set 9 | inongo
# Processing Record 43 of Set 9 | cockburn town
# Processing Record 44 of Set 9 | witrivier
# City not found. Skipping...
# Processing Record 45 of Set 9 | oliveira dos brejinhos
# Processing Record 46 of Set 9 | atambua
# Processing Record 47 of Set 9 | manado
# Processing Record 48 of Set 9 | hithadhoo
# Processing Record 49 of Set 9 | telimele
# Processing Record 50 of Set 9 | mayang imphal
# Processing Record 1 of Set 10 | fugen
# Processing Record 2 of Set 10 | abay
# Processing Record 3 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 10 | damara
# Processing Record 5 of Set 10 | sena madureira
# Processing Record 6 of Set 10 | sondrio
# Processing Record 7 of Set 10 | warmbad
# Processing Record 8 of Set 10 | moniquira
# Processing Record 9 of Set 10 | marrakesh
# Processing Record 10 of Set 10 | mandalgovi
# Processing Record 11 of Set 10 | igarka
# Processing Record 12 of Set 10 | laurel
# Processing Record 13 of Set 10 | bull savanna
# Processing Record 14 of Set 10 | lagoa
# Processing Record 15 of Set 10 | florianopolis
# Processing Record 16 of Set 10 | egvekinot
# Processing Record 17 of Set 10 | baghdad
# Processing Record 18 of Set 10 | atherton
# Processing Record 19 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 10 | jacareacanga
# Processing Record 21 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 22 of Set 10 | elko
# Processing Record 23 of Set 10 | jian
# Processing Record 24 of Set 10 | barra patuca
# Processing Record 25 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 10 | bandarbeyla
# Processing Record 27 of Set 10 | gandu
# Processing Record 28 of Set 10 | rio gallegos
# Processing Record 29 of Set 10 | jasper
# Processing Record 30 of Set 10 | puro
# Processing Record 31 of Set 10 | harrison
# Processing Record 32 of Set 10 | san quintin
# Processing Record 33 of Set 10 | virginia beach
# Processing Record 34 of Set 10 | alyangula
# Processing Record 35 of Set 10 | champua
# Processing Record 36 of Set 10 | iquique
# Processing Record 37 of Set 10 | do rud
# City not found. Skipping...
# Processing Record 38 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 10 | mackay
# Processing Record 40 of Set 10 | villa de cura
# Processing Record 41 of Set 10 | nalut
# Processing Record 42 of Set 10 | calvinia
# Processing Record 43 of Set 10 | magaria
# Processing Record 44 of Set 10 | kenora
# Processing Record 45 of Set 10 | eston
# Processing Record 46 of Set 10 | cap-aux-meules
# Processing Record 47 of Set 10 | qasigiannguit
# Processing Record 48 of Set 10 | kaliua
# Processing Record 49 of Set 10 | cuiluan
# Processing Record 50 of Set 10 | seoul
# Processing Record 1 of Set 11 | tenenkou
# Processing Record 2 of Set 11 | malinovoye ozero
# Processing Record 3 of Set 11 | andenes
# Processing Record 4 of Set 11 | simdega
# Processing Record 5 of Set 11 | chicama
# Processing Record 6 of Set 11 | haines junction
# Processing Record 7 of Set 11 | makaleng
# Processing Record 8 of Set 11 | puerto escondido
# Processing Record 9 of Set 11 | normandin
# Processing Record 10 of Set 11 | harper
# Processing Record 11 of Set 11 | lompoc
# Processing Record 12 of Set 11 | alakurtti
# Processing Record 13 of Set 11 | pangoa
# Processing Record 14 of Set 11 | quincy
# Processing Record 15 of Set 11 | kiunga
# Processing Record 16 of Set 11 | barcarena
# Processing Record 17 of Set 11 | college
# Processing Record 18 of Set 11 | arroyo
# Processing Record 19 of Set 11 | timizart
# Processing Record 20 of Set 11 | juneau
# Processing Record 21 of Set 11 | diapaga
# Processing Record 22 of Set 11 | marapanim
# Processing Record 23 of Set 11 | margate
# Processing Record 24 of Set 11 | hualmay
# Processing Record 25 of Set 11 | ibra
# Processing Record 26 of Set 11 | bengkulu
# Processing Record 27 of Set 11 | alice springs
# Processing Record 28 of Set 11 | wanaka
# Processing Record 29 of Set 11 | enugu
# Processing Record 30 of Set 11 | bafoulabe
# Processing Record 31 of Set 11 | lagunas
# Processing Record 32 of Set 11 | bratsk
# Processing Record 33 of Set 11 | valenca
# Processing Record 34 of Set 11 | tungor
# Processing Record 35 of Set 11 | isangel
# Processing Record 36 of Set 11 | puerto ayacucho
# Processing Record 37 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 38 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 11 | buta
# Processing Record 40 of Set 11 | salinas
# Processing Record 41 of Set 11 | rennes
# Processing Record 42 of Set 11 | high level
# Processing Record 43 of Set 11 | kemijarvi
# Processing Record 44 of Set 11 | labytnangi
# Processing Record 45 of Set 11 | kulykiv
# Processing Record 46 of Set 11 | zhigansk
# Processing Record 47 of Set 11 | tibiri
# Processing Record 48 of Set 11 | chaves
# Processing Record 49 of Set 11 | birjand
# Processing Record 50 of Set 11 | boshnyakovo
# Processing Record 1 of Set 12 | chegdomyn
# Processing Record 2 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 4 of Set 12 | sorland
# Processing Record 5 of Set 12 | grindavik
# Processing Record 6 of Set 12 | loreto
# Processing Record 7 of Set 12 | ust-tsilma
# Processing Record 8 of Set 12 | fare
# Processing Record 9 of Set 12 | traverse city
# Processing Record 10 of Set 12 | decatur
# Processing Record 11 of Set 12 | pesqueira
# Processing Record 12 of Set 12 | the valley
# Processing Record 13 of Set 12 | tkibuli
# Processing Record 14 of Set 12 | zhigalovo
# Processing Record 15 of Set 12 | mbandaka
# Processing Record 16 of Set 12 | baiyin
# Processing Record 17 of Set 12 | haapiti
# Processing Record 18 of Set 12 | kutahya
# Processing Record 19 of Set 12 | jumla
# Processing Record 20 of Set 12 | kyra
# Processing Record 21 of Set 12 | umm lajj
# Processing Record 22 of Set 12 | linxia
# Processing Record 23 of Set 12 | cerquilho
# Processing Record 24 of Set 12 | avera
# Processing Record 25 of Set 12 | goure
# Processing Record 26 of Set 12 | port lincoln
# Processing Record 27 of Set 12 | pudozh
# Processing Record 28 of Set 12 | balaipungut
# Processing Record 29 of Set 12 | ejido
# Processing Record 30 of Set 12 | aklavik
# Processing Record 31 of Set 12 | katherine
# Processing Record 32 of Set 12 | sabzevar
# Processing Record 33 of Set 12 | trindade
# Processing Record 34 of Set 12 | svetlogorsk
# Processing Record 35 of Set 12 | muana
# Processing Record 36 of Set 12 | henties bay
# Processing Record 37 of Set 12 | vestmannaeyjar
# Processing Record 38 of Set 12 | plettenberg bay
# Processing Record 39 of Set 12 | hinton
# Processing Record 40 of Set 12 | chincholi
# Processing Record 41 of Set 12 | maturin
# Processing Record 42 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 43 of Set 12 | mokrous
# Processing Record 44 of Set 12 | puerto quijarro
# Processing Record 45 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 12 | khandyga
# Processing Record 47 of Set 12 | katobu
# Processing Record 48 of Set 12 | brigantine
# Processing Record 49 of Set 12 | merauke
# Processing Record 50 of Set 12 | tazmalt
# Processing Record 1 of Set 13 | viedma
# Processing Record 2 of Set 13 | mushie
# Processing Record 3 of Set 13 | samarai
# Processing Record 4 of Set 13 | vikhorevka
# Processing Record 5 of Set 13 | mount gambier
# Processing Record 6 of Set 13 | wangqing
# Processing Record 7 of Set 13 | adre
# Processing Record 8 of Set 13 | ullapool
# Processing Record 9 of Set 13 | trzic
# Processing Record 10 of Set 13 | grants
# Processing Record 11 of Set 13 | jutai
# Processing Record 12 of Set 13 | dakar
# Processing Record 13 of Set 13 | castelo branco
# Processing Record 14 of Set 13 | crystal beach
# Processing Record 15 of Set 13 | lephepe
# City not found. Skipping...
# Processing Record 16 of Set 13 | lodeynoye pole
# Processing Record 17 of Set 13 | bay city
# Processing Record 18 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 13 | haukipudas
# Processing Record 20 of Set 13 | ishigaki
# Processing Record 21 of Set 13 | gorkovskoye
# City not found. Skipping...
# Processing Record 22 of Set 13 | miri
# Processing Record 23 of Set 13 | laguna
# Processing Record 24 of Set 13 | santa barbara
# Processing Record 25 of Set 13 | nagua
# Processing Record 26 of Set 13 | trinidad
# Processing Record 27 of Set 13 | nizhniy kuranakh
# Processing Record 28 of Set 13 | gazli
# Processing Record 29 of Set 13 | belmonte
# Processing Record 30 of Set 13 | gizo
# Processing Record 31 of Set 13 | mossendjo
# Processing Record 32 of Set 13 | edd
# Processing Record 33 of Set 13 | thanh hoa
# Processing Record 34 of Set 13 | little current
# Processing Record 35 of Set 13 | pemba
# Processing Record 36 of Set 13 | jundubah
# City not found. Skipping...
# Processing Record 37 of Set 13 | belaya gora
# Processing Record 38 of Set 13 | sarti
# Processing Record 39 of Set 13 | katsuura
# Processing Record 40 of Set 13 | chany
# Processing Record 41 of Set 13 | gravdal
# Processing Record 42 of Set 13 | nioro
# Processing Record 43 of Set 13 | koson
# Processing Record 44 of Set 13 | orangeburg
# Processing Record 45 of Set 13 | pringsewu
# Processing Record 46 of Set 13 | fallon
# Processing Record 47 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 13 | antalaha
# Processing Record 49 of Set 13 | estelle
# Processing Record 50 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 14 | ketchikan
# Processing Record 2 of Set 14 | kahului
# Processing Record 3 of Set 14 | adiake
# Processing Record 4 of Set 14 | atar
# Processing Record 5 of Set 14 | te anau
# Processing Record 6 of Set 14 | tabas
# Processing Record 7 of Set 14 | lokosovo
# Processing Record 8 of Set 14 | doha
# Processing Record 9 of Set 14 | khorixas
# Processing Record 10 of Set 14 | ola
# Processing Record 11 of Set 14 | sagua la grande
# Processing Record 12 of Set 14 | warwick
# Processing Record 13 of Set 14 | lakatoro
# Processing Record 14 of Set 14 | langham
# Processing Record 15 of Set 14 | vostok
# Processing Record 16 of Set 14 | santa isabel
# Processing Record 17 of Set 14 | taybad
# Processing Record 18 of Set 14 | grootfontein
# Processing Record 19 of Set 14 | moose factory
# Processing Record 20 of Set 14 | mogadishu
# Processing Record 21 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 14 | diamantino
# Processing Record 23 of Set 14 | shenkursk
# Processing Record 24 of Set 14 | dharchula
# Processing Record 25 of Set 14 | sisimiut
# Processing Record 26 of Set 14 | izhma
# Processing Record 27 of Set 14 | nisia floresta
# Processing Record 28 of Set 14 | maubin
# Processing Record 29 of Set 14 | golden
# Processing Record 30 of Set 14 | ankang
# Processing Record 31 of Set 14 | iwanai
# Processing Record 32 of Set 14 | marzuq
# Processing Record 33 of Set 14 | bogashevo
# Processing Record 34 of Set 14 | primero de enero
# Processing Record 35 of Set 14 | shirgaon
# Processing Record 36 of Set 14 | polunochnoye
# Processing Record 37 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 38 of Set 14 | colares
# Processing Record 39 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 40 of Set 14 | yellandu
# Processing Record 41 of Set 14 | farafangana
# Processing Record 42 of Set 14 | ordu
# Processing Record 43 of Set 14 | middlebury
# Processing Record 44 of Set 14 | katangli
# Processing Record 45 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 46 of Set 14 | kenai
# Processing Record 47 of Set 14 | inhambane
# Processing Record 48 of Set 14 | birao
# Processing Record 49 of Set 14 | stykkisholmur
# Processing Record 50 of Set 14 | kidodi
# Processing Record 1 of Set 15 | matay
# Processing Record 2 of Set 15 | nuristan
# Processing Record 3 of Set 15 | tombouctou
# Processing Record 4 of Set 15 | yarmouth
# Processing Record 5 of Set 15 | kruisfontein
# Processing Record 6 of Set 15 | meghri
# Processing Record 7 of Set 15 | buala
# Processing Record 8 of Set 15 | bogovarovo
# Processing Record 9 of Set 15 | cap malheureux
# Processing Record 10 of Set 15 | jiwani
# Processing Record 11 of Set 15 | pishin
# Processing Record 12 of Set 15 | nouadhibou
# Processing Record 13 of Set 15 | yar-sale
# Processing Record 14 of Set 15 | kungurtug
# Processing Record 15 of Set 15 | cardenas
# Processing Record 16 of Set 15 | hami
# Processing Record 17 of Set 15 | sola
# Processing Record 18 of Set 15 | desaguadero
# Processing Record 19 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 15 | tay ninh
# Processing Record 21 of Set 15 | haradok
# Processing Record 22 of Set 15 | la rioja
# Processing Record 23 of Set 15 | barsi
# Processing Record 24 of Set 15 | chifeng
# Processing Record 25 of Set 15 | portland
# Processing Record 26 of Set 15 | gamba
# Processing Record 27 of Set 15 | san carlos
# Processing Record 28 of Set 15 | honiton
# Processing Record 29 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 30 of Set 15 | highland springs
# Processing Record 31 of Set 15 | srednekolymsk
# Processing Record 32 of Set 15 | nongpoh
# Processing Record 33 of Set 15 | strezhevoy
# Processing Record 34 of Set 15 | liepaja
# Processing Record 35 of Set 15 | melong
# Processing Record 36 of Set 15 | manakara
# Processing Record 37 of Set 15 | aykhal
# Processing Record 38 of Set 15 | cabedelo
# Processing Record 39 of Set 15 | nishihara
# Processing Record 40 of Set 15 | pingliang
# Processing Record 41 of Set 15 | gaozhou
# Processing Record 42 of Set 15 | kachhwa
# Processing Record 43 of Set 15 | kariba
# Processing Record 44 of Set 15 | labuan
# Processing Record 45 of Set 15 | sembakung
# Processing Record 46 of Set 15 | champerico
# Processing Record 47 of Set 15 | anadyr
# Processing Record 48 of Set 15 | wanning
# Processing Record 49 of Set 15 | ula
# Processing Record 50 of Set 15 | kaabong
# Processing Record 1 of Set 16 | bell ville
# Processing Record 2 of Set 16 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 16 | san cristobal
# Processing Record 4 of Set 16 | dzhebariki-khaya
# Processing Record 5 of Set 16 | ileza
# Processing Record 6 of Set 16 | sinnamary
# Processing Record 7 of Set 16 | segou
# Processing Record 8 of Set 16 | coxim
# Processing Record 9 of Set 16 | ous
# Processing Record 10 of Set 16 | waingapu
# Processing Record 11 of Set 16 | port hardy
# Processing Record 12 of Set 16 | oranjemund
# Processing Record 13 of Set 16 | ugoofaaru
# Processing Record 14 of Set 16 | bolshoye murashkino
# Processing Record 15 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 16 | shimoda
# Processing Record 17 of Set 16 | kitgum
# Processing Record 18 of Set 16 | marsa matruh
# Processing Record 19 of Set 16 | yandoon
# City not found. Skipping...
# Processing Record 20 of Set 16 | goderich
# Processing Record 21 of Set 16 | zemio
# Processing Record 22 of Set 16 | sioux lookout
# Processing Record 23 of Set 16 | yerbogachen
# Processing Record 24 of Set 16 | elizabeth city
# Processing Record 25 of Set 16 | tumbi
# Processing Record 26 of Set 16 | damietta
# Processing Record 27 of Set 16 | namibe
# Processing Record 28 of Set 16 | sambava
# Processing Record 29 of Set 16 | urengoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.tail(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 709        Goderich  43.7501  -81.7165     39.52        56          95
# 710           Zemio   5.0314   25.1361     69.12        88          23
# 711   Sioux Lookout  50.1001  -91.9170     28.78        74          75
# 712     Yerbogachen  61.2767  108.0108      1.53        92          49
# 713  Elizabeth City  36.2946  -76.2511     48.22        67           1
# 714           Tumbi  -5.0667   32.7333     70.29        56          82
# 715        Damietta  31.4165   31.8133     62.49        81         100
# 716          Namibe -15.1961   12.1522     70.38        68          51
# 717         Sambava -14.2667   50.1667     76.37        77          37
# 718         Urengoy  65.9667   78.3667    -15.63        98          80
#
#      Wind Speed Country Current Description                 Date
# 709        9.22      CA     overcast clouds  2021-11-20 03:40:06
# 710        1.43      CF          few clouds  2021-11-20 03:40:06
# 711        8.05      CA       broken clouds  2021-11-20 03:40:07
# 712        3.85      RU    scattered clouds  2021-11-20 03:40:07
# 713        9.22      US           clear sky  2021-11-20 03:40:07
# 714        0.22      TZ       broken clouds  2021-11-20 03:40:07
# 715       10.89      EG     overcast clouds  2021-11-20 03:40:08
# 716        6.85      AO       broken clouds  2021-11-20 03:40:08
# 717        6.06      MG          light rain  2021-11-20 03:40:08
# 718       11.21      RU       broken clouds  2021-11-20 03:40:08

# %%
# Rearrange columns
new_col_order = ['City', 'Country',  'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_col_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Puerto Ayora      EC  -0.7393  -90.3518     68.56        92          54
# 1  Leningradskiy      RU  69.3833  178.4167     -3.62        82          92
# 2          Kapaa      US  22.0752 -159.3190     82.38        75          20
# 3         Barrow      US  71.2906 -156.7887     10.42        79          90
# 4       Cidreira      BR -30.1811  -50.2056     62.29        72           0
# 5      Busselton      AU -33.6500  115.3333     76.08        44          15
# 6         Hobart      AU -42.8794  147.3294     64.11        69          75
# 7      Maniitsoq      GL  65.4167  -52.9000     26.83        60         100
# 8     Nikolskoye      RU  59.7035   30.7861     35.49        97         100
# 9  Moreira Sales      BR -24.0622  -53.0069     65.66        75           0
#
#    Wind Speed Current Description
# 0        4.00       broken clouds
# 1        4.68     overcast clouds
# 2        1.01          few clouds
# 3        5.75          light snow
# 4        6.71           clear sky
# 5        7.74          few clouds
# 6        1.01       broken clouds
# 7       21.61     overcast clouds
# 8        9.57     overcast clouds
# 9        5.64           clear sky

# %%
# Create the output file (CSV).
output_dafile = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
